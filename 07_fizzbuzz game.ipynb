# %%
for i in range(1,101):
 if i%3==0:
  print ("fizz") 
 if i%5==0:
  print ("buzz")
 if i%5==0 and i%3==0:  
  print("fizzbuzz")
# Out:
# fizz
# buzz
# fizz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizzbuzz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizzbuzz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizzbuzz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizzbuzz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizzbuzz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizz
# fizz
# buzz
# fizzbuzz
# fizz
# buzz
# fizz
# fizz
# buzz
